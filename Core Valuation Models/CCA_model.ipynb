# %% [markdown]
# <h1>Comparable Company Analysis</h1>
#
# <p>The outline of this project is to automate the CCA model with python, choosing a selection of firms and comparing it to the firm of choice.</p>
#
# <p>CCA model consists of finding certain metrics such as P/E and using it to find an average for the chosen industry, this can then be compared to the firm of choice.</p>

# %%
# Importing required libraries
import yfinance as yf
import pandas as pd
